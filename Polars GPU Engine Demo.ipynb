# %% [markdown]
# ## Intro
#
# Polars is a popular single machine DataFrame library powered by an OLAP Query Engine. Beginning in the v1.3 release, Polars can now leverage NVIDIA GPUs for even higher performance through its GPU engine (powered by RAPIDS cuDF).
#
# This new engine is built directly into the Polars Lazy API – just pass <font color="#76B900">**engine="gpu"**</font> to the `collect` operation.

# %% [markdown]
# # Setup

# %% [markdown]
# ## Installing the Polars GPU Engine
#
# Install Polars with GPU Engine by using a feature flag in the standard pip install command  `pip install polars[gpu] --extra-index-url=https://pypi.nvidia.com`.

# %%
# !pip install polars==1.5
# !pip install "/content/cudf_polars_cu11-24.8.0a433-py3-none-any.whl" --extra-index-url=https://pypi.anaconda.org/rapidsai-wheels-nightly/simple
# Out:
# Requirement already satisfied: polars==1.5 in /usr/local/lib/python3.10/dist-packages (1.5.0)
# Looking in indexes: https://pypi.org/simple, https://pypi.anaconda.org/rapidsai-wheels-nightly/simple
# Processing ./cudf_polars_cu11-24.8.0a433-py3-none-any.whl
# Collecting cudf-cu11==24.8.*,>=0.0.0a0 (from cudf-polars-cu11==24.8.0a433)
#   Downloading cudf_cu11-24.8.2.tar.gz (2.6 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: polars>=1.3 in /usr/local/lib/python3.10/dist-packages (from cudf-polars-cu11==24.8.0a433) (1.5.0)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from cudf-cu11==24.8.*,>=0.0.0a0->cudf-polars-cu11==24.8.0a433) (5.5.0)
# Collecting cubinlinker-cu11 (from cudf-cu11==24.8.*,>=0.0.0a0->cudf-polars-cu11==24.8.0a433)
#   Downloading https://pypi.anaconda.org/rapidsai-wheels-nightly/simple/cubinlinker-cu11/0.3.0.post2/cubinlinker_cu11-0.3.0.post2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 4.0 MB/s eta 0:00:00
# Collecting cuda-python<12.0a0,>=11.7.1 (from cudf-cu11==24.8.*,>=0.0.0a0->cudf-polars-cu11==24.8.0a433)
#   Downloading cuda_python-11.8.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting cupy-cuda11x>=12.0.0 (from cudf-cu11==24.8.*,>=0.0.0a0->cudf-polars-cu11==24.8.0a433)
#   Downloading cupy_cuda11x-13.3.0-cp310-cp310-manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from cudf-cu11==24.8.*,>=0.0.0a0->cudf-polars-cu11==24.8.0a433) (2024.6.1)
# Requirement already satisfied: numba>=0.57 in /usr/local/lib/python3.10/dist-packages (from cudf-cu11==24.8.*,>=0.0.0a0->cudf-polars-cu11==24.8.0a433) (0.60.0)
# Requirement already satisfied: numpy<2.0a0,>=1.23 in /usr/local/lib/python3.10/dist-packages (from cudf-cu11==24.8.*,>=0.0.0a0->cudf-polars-cu11==24.8.0a433) (1.26.4)
# Requirement already satisfied: nvtx>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from cudf-cu11==24.8.*,>=0.0.0a0->cudf-polars-cu11==24.8.0a433) (0.2.10)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from cudf-cu11==24.8.*,>=0.0.0a0->cudf-polars-cu11==24.8.0a433) (24.1)
# Requirement already satisfied: pandas<2.2.3dev0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from cudf-cu11==24.8.*,>=0.0.0a0->cudf-polars-cu11==24.8.0a433) (2.1.4)
# Collecting ptxcompiler-cu11 (from cudf-cu11==24.8.*,>=0.0.0a0->cudf-polars-cu11==24.8.0a433)
#   Downloading https://pypi.anaconda.org/rapidsai-wheels-nightly/simple/ptxcompiler-cu11/0.8.1.post2/ptxcompiler_cu11-0.8.1.post2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (8.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 18.0 MB/s eta 0:00:00
# Collecting pyarrow<16.2.0a0,>=16.1.0 (from cudf-cu11==24.8.*,>=0.0.0a0->cudf-polars-cu11==24.8.0a433)
#   Downloading pyarrow-16.1.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from cudf-cu11==24.8.*,>=0.0.0a0->cudf-polars-cu11==24.8.0a433) (13.8.1)
# Collecting rmm-cu11==24.8.* (from cudf-cu11==24.8.*,>=0.0.0a0->cudf-polars-cu11==24.8.0a433)
#   Downloading rmm_cu11-24.8.2.tar.gz (13 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: typing_extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from cudf-cu11==24.8.*,>=0.0.0a0->cudf-polars-cu11==24.8.0a433) (4.12.2)
# Requirement already satisfied: fastrlock>=0.5 in /usr/local/lib/python3.10/dist-packages (from cupy-cuda11x>=12.0.0->cudf-cu11==24.8.*,>=0.0.0a0->cudf-polars-cu11==24.8.0a433) (0.8.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.57->cudf-cu11==24.8.*,>=0.0.0a0->cudf-polars-cu11==24.8.0a433) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<2.2.3dev0,>=2.0->cudf-cu11==24.8.*,>=0.0.0a0->cudf-polars-cu11==24.8.0a433) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.2.3dev0,>=2.0->cudf-cu11==24.8.*,>=0.0.0a0->cudf-polars-cu11==24.8.0a433) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.2.3dev0,>=2.0->cudf-cu11==24.8.*,>=0.0.0a0->cudf-polars-cu11==24.8.0a433) (2024.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->cudf-cu11==24.8.*,>=0.0.0a0->cudf-polars-cu11==24.8.0a433) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->cudf-cu11==24.8.*,>=0.0.0a0->cudf-polars-cu11==24.8.0a433) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->cudf-cu11==24.8.*,>=0.0.0a0->cudf-polars-cu11==24.8.0a433) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<2.2.3dev0,>=2.0->cudf-cu11==24.8.*,>=0.0.0a0->cudf-polars-cu11==24.8.0a433) (1.16.0)
# Downloading cuda_python-11.8.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.7/18.7 MB 80.0 MB/s eta 0:00:00
# Downloading cupy_cuda11x-13.3.0-cp310-cp310-manylinux2014_x86_64.whl (96.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 MB 9.5 MB/s eta 0:00:00
# Downloading pyarrow-16.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (40.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 15.9 MB/s eta 0:00:00
# Building wheels for collected packages: cudf-cu11, rmm-cu11
#   Building wheel for cudf-cu11 (pyproject.toml) ... done
#   Created wheel for cudf-cu11: filename=cudf_cu11-24.8.2-cp310-cp310-manylinux_2_28_x86_64.whl size=508918902 sha256=6e5bddab29fa53150e52048f560d4d538fad5ce39d71e746ef88aa8fa745fdc4
#   Stored in directory: /root/.cache/pip/wheels/f4/90/ef/978ff4281ef517f6cb62084e7b8e933d3a38f7372802e3d674
#   Building wheel for rmm-cu11 (pyproject.toml) ... done
#   Created wheel for rmm-cu11: filename=rmm_cu11-24.8.2-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl size=1704985 sha256=707e19131cf808c0350b26df993d65767b1d13b55ba4889393ac02751caf0153
#   Stored in directory: /root/.cache/pip/wheels/8d/de/2d/d98faf99686a094e8e6b99eb501e38ef24f44d02a6cb9fce8b
# Successfully built cudf-cu11 rmm-cu11
# Installing collected packages: ptxcompiler-cu11, cuda-python, pyarrow, cupy-cuda11x, cubinlinker-cu11, rmm-cu11, cudf-cu11, cudf-polars-cu11
#   Attempting uninstall: cuda-python
#     Found existing installation: cuda-python 12.2.1
#     Uninstalling cuda-python-12.2.1:
#       Successfully uninstalled cuda-python-12.2.1
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires cuda-python<13.0a0,>=12.0, but you have cuda-python 11.8.3 which is incompatible.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 16.1.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 16.1.0 which is incompatible.
# rmm-cu12 24.4.0 requires cuda-python<13.0a0,>=12.0, but you have cuda-python 11.8.3 which is incompatible.
# Successfully installed cubinlinker-cu11-0.3.0.post2 cuda-python-11.8.3 cudf-cu11-24.8.2 cudf-polars-cu11-24.8.0a433 cupy-cuda11x-13.3.0 ptxcompiler-cu11-0.8.1.post2 pyarrow-16.1.0 rmm-cu11-24.8.2

# %% [markdown]
# ## Download the Data
#
# We'll be working with a roughly 22GB dataset of [simulated financial transactions from Kaggle](https://www.kaggle.com/datasets/conorsully1/simulated-transactions) by default. If you're running this notebook on Google Colab using the T4 GPU in the Colab free tier, make sure you set `GOOGLE_COLAB=True` below to download a smaller version of this dataset (about 20% of the size) to fit on the relatively weaker CPU and GPU.
#
# We're downloading a copy of this dataset from a GCS bucket hosted by NVIDIA to provide faster download speeds. We'll start by downloading the data. This should take about 30 seconds.

# %%
# !wget https://storage.googleapis.com/rapidsai/polars-demo/transactions-t4-20.parquet -O transactions.parquet
# Out:
# --2024-09-16 21:48:41--  https://storage.googleapis.com/rapidsai/polars-demo/transactions-t4-20.parquet
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.251.175.207, 74.125.24.207, 142.251.10.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.251.175.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 857658422 (818M) [application/octet-stream]
# Saving to: ‘transactions.parquet’
#
# transactions.parque 100%[===================>] 817.93M  22.8MB/s    in 38s
#
# 2024-09-16 21:49:20 (21.4 MB/s) - ‘transactions.parquet’ saved [857658422/857658422]

# %% [markdown]
# # Getting Started

# %%
import polars as pl
from polars.testing import assert_frame_equal

# %%
transactions = pl.scan_parquet("transactions.parquet")

# %%
transactions.collect_schema()
# Out:
# Schema([('CUST_ID', String),
#         ('START_DATE', Date),
#         ('END_DATE', Date),
#         ('TRANS_ID', String),
#         ('DATE', Date),
#         ('YEAR', Int64),
#         ('MONTH', Int64),
#         ('DAY', Int64),
#         ('EXP_TYPE', String),
#         ('AMOUNT', Float64)])

# %%
transactions.head(5).collect()
# Out:
# shape: (5, 10)
# ┌────────────┬────────────┬──────────┬─────────────────┬───┬───────┬─────┬───────────────┬────────┐
# │ CUST_ID    ┆ START_DATE ┆ END_DATE ┆ TRANS_ID        ┆ … ┆ MONTH ┆ DAY ┆ EXP_TYPE      ┆ AMOUNT │
# │ ---        ┆ ---        ┆ ---      ┆ ---             ┆   ┆ ---   ┆ --- ┆ ---           ┆ ---    │
# │ str        ┆ date       ┆ date     ┆ str             ┆   ┆ i64   ┆ i64 ┆ str           ┆ f64    │
# ╞════════════╪════════════╪══════════╪═════════════════╪═══╪═══════╪═════╪═══════════════╪════════╡
# │ CI6XLYUMQK ┆ 2015-05-01 ┆ null     ┆ T8I9ZB5A6X90UG8 ┆ … ┆ 9     ┆ 11  ┆ Motor/Travel  ┆ 20.27  │
# │ CI6XLYUMQK ┆ 2015-05-01 ┆ null     ┆ TZ4JSLS7SC7FO9H ┆ … ┆ 2     ┆ 8   ┆ Motor/Travel  ┆ 12.85  │
# │ CI6XLYUMQK ┆ 2015-05-01 ┆ null     ┆ TTUKRDDJ6B6F42H ┆ … ┆ 8     ┆ 1   ┆ Housing       ┆ 383.8  │
# │ CI6XLYUMQK ┆ 2015-05-01 ┆ null     ┆ TDUHFRUKGPPI6HD ┆ … ┆ 3     ┆ 16  ┆ Entertainment ┆ 5.72   │
# │ CI6XLYUMQK ┆ 2015-05-01 ┆ null     ┆ T0JBZHBMSVRFMMD ┆ … ┆ 5     ┆ 15  ┆ Entertainment ┆ 11.06  │
# └────────────┴────────────┴──────────┴─────────────────┴───┴───────┴─────┴───────────────┴────────┘

# %% [markdown]
# First operation: Total aggregate transaction amount

# %%
# %%time
transactions.select(pl.col("AMOUNT").sum()).collect()
# Out:
# CPU times: user 1.45 s, sys: 358 ms, total: 1.81 s
# Wall time: 1.08 s
# shape: (1, 1)
# ┌──────────┐
# │ AMOUNT   │
# │ ---      │
# │ f64      │
# ╞══════════╡
# │ 3.6183e9 │
# └──────────┘

# %%
# %%time
transactions.select(pl.col("AMOUNT").sum()).collect(engine="gpu")
# Out:
# CPU times: user 2.15 s, sys: 662 ms, total: 2.82 s
# Wall time: 3.76 s
# shape: (1, 1)
# ┌──────────┐
# │ AMOUNT   │
# │ ---      │
# │ f64      │
# ╞══════════╡
# │ 3.6183e9 │
# └──────────┘

# %%
transactions.collect().shape
# Out:
# (52393943, 10)

# %%
gpu_engine = pl.GPUEngine(
    device=0,
    raise_on_fail=True,
)

# %% [markdown]
# The very first collection on the GPU will take a couple of seconds. The GPU engine is lazy-loaded so that even if the necessary packages are installed, Polars' fast import times are not affected. Consequently, when we trigger GPU execution for the first time, we load a number of additional packages, and initialize GPU-specific data structures and contexts.

# %%
# %%time
transactions.select(pl.col("AMOUNT").sum()).collect(engine=gpu_engine)
# Out:
# CPU times: user 298 ms, sys: 30.4 ms, total: 329 ms
# Wall time: 394 ms
# shape: (1, 1)
# ┌──────────┐
# │ AMOUNT   │
# │ ---      │
# │ f64      │
# ╞══════════╡
# │ 3.6183e9 │
# └──────────┘

# %% [markdown]
# # More Complex Analysis

# %% [markdown]
# While the data is synthetic, it's representative of the kinds of datasets that come up in financial services, retail/e-commerce, consumer internet, and other industries.
#
# With this data, we can see how using GPU-accelerated Polars provides a significant productivity boosts by exploring common business questions like which customers have the largest total transctions?

# %% [markdown]
# ## Which customers have the largest total transactions?

# %%
# %%time

high_spenders_cpu = (
    transactions
    .group_by("CUST_ID")
    .agg(pl.col("AMOUNT").sum())
    .sort(by="AMOUNT", descending=True)
    .head()
    .collect()
)
high_spenders_cpu
# Out:
# CPU times: user 4.27 s, sys: 2.46 s, total: 6.73 s
# Wall time: 4.41 s
# shape: (5, 2)
# ┌────────────┬──────────┐
# │ CUST_ID    ┆ AMOUNT   │
# │ ---        ┆ ---      │
# │ str        ┆ f64      │
# ╞════════════╪══════════╡
# │ CA9UYOQ5DA ┆ 2.0290e6 │
# │ CJUK2MTM5Q ┆ 1.8115e6 │
# │ CYXX1NBIKL ┆ 1.8082e6 │
# │ C6ILEYAYQ9 ┆ 1.7961e6 │
# │ CCNBC305GI ┆ 1.7274e6 │
# └────────────┴──────────┘

# %%
# %%time

high_spenders_gpu = (
    transactions
    .group_by("CUST_ID")
    .agg(pl.col("AMOUNT").sum())
    .sort(by="AMOUNT", descending=True)
    .head()
    .collect(engine=gpu_engine)
)
high_spenders_gpu
# Out:
# CPU times: user 345 ms, sys: 40.5 ms, total: 385 ms
# Wall time: 397 ms
# shape: (5, 2)
# ┌────────────┬──────────┐
# │ CUST_ID    ┆ AMOUNT   │
# │ ---        ┆ ---      │
# │ str        ┆ f64      │
# ╞════════════╪══════════╡
# │ CA9UYOQ5DA ┆ 2.0290e6 │
# │ CJUK2MTM5Q ┆ 1.8115e6 │
# │ CYXX1NBIKL ┆ 1.8082e6 │
# │ C6ILEYAYQ9 ┆ 1.7961e6 │
# │ CCNBC305GI ┆ 1.7274e6 │
# └────────────┴──────────┘

# %% [markdown]
# In addition to the Dataframe interface, Polars also has an SQL interface. We can also use this with the GPU engine, since Polars translates both the DataFrame and SQL interfaces into a query execution plan.

# %%
sql_query = """
SELECT CUST_ID, SUM(AMOUNT) as sum_amt
FROM transactions
GROUP BY CUST_ID
ORDER BY sum_amt desc
LIMIT 5
"""

# %time pl.sql(sql_query).collect()
# %time pl.sql(sql_query).collect(engine=gpu_engine)
# Out:
# CPU times: user 4.39 s, sys: 2.5 s, total: 6.89 s
# Wall time: 4.53 s
# CPU times: user 336 ms, sys: 39.2 ms, total: 376 ms
# Wall time: 356 ms
# shape: (5, 2)
# ┌────────────┬──────────┐
# │ CUST_ID    ┆ sum_amt  │
# │ ---        ┆ ---      │
# │ str        ┆ f64      │
# ╞════════════╪══════════╡
# │ CA9UYOQ5DA ┆ 2.0290e6 │
# │ CJUK2MTM5Q ┆ 1.8115e6 │
# │ CYXX1NBIKL ┆ 1.8082e6 │
# │ C6ILEYAYQ9 ┆ 1.7961e6 │
# │ CCNBC305GI ┆ 1.7274e6 │
# └────────────┴──────────┘
